# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#GPU-vs-CPU-setup" data-toc-modified-id="GPU-vs-CPU-setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>GPU vs CPU setup</a></span><ul class="toc-item"><li><span><a href="#GPU" data-toc-modified-id="GPU-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>GPU</a></span></li><li><span><a href="#CPU" data-toc-modified-id="CPU-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>CPU</a></span></li><li><span><a href="#Tensorflow-2.4" data-toc-modified-id="Tensorflow-2.4-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Tensorflow 2.4</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Model</a></span></li></ul></li><li><span><a href="#Before-and-after-using-GPU" data-toc-modified-id="Before-and-after-using-GPU-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Before and after using GPU</a></span><ul class="toc-item"><li><span><a href="#Cuda-usage" data-toc-modified-id="Cuda-usage-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Cuda usage</a></span></li></ul></li></ul></div>

# %% [markdown]
# # GPU vs CPU setup

# %% [markdown]
# ## GPU
# RTX 3060Ti
#
# 8GB VRAM
# ## CPU
# AMD 3700X
#
# 8 physical cores
# ## Tensorflow 2.4
#
# ## Model
#
# Dfl-H128 in faceswap
#
# input size 512
#
# batch size 16

# %% [markdown]
# # Before and after using GPU

# %%
from IPython.display import Image
Image(r"E:\data\faceswap\projects\yangliu\image.png")

# %%
print("speed up by a factor of", 70/2.8)
# Out:
# speed up by a factor of 25.0

# %% [markdown]
# ## Cuda usage

# %%
from IPython.display import Image
Image(r"E:\data\faceswap\projects\yangliu\cuda.png")
